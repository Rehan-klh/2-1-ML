# %%
import pandas as pd
from scipy.sparse import load_npz

X_train = load_npz("../data/processed/X_train.npz")
X_test = load_npz("../data/processed/X_test.npz")

y_train = pd.read_csv("../data/processed/y_train.csv").squeeze()
y_test = pd.read_csv("../data/processed/y_test.csv").squeeze()

print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (160281, 180468)
# X_test : (40071, 180468)
# y_train: (160281,)
# y_test : (40071,)

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(
    max_iter=1000,
    random_state=42
)

lr_model.fit(X_train, y_train)

print("Logistic Regression training complete.")

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

y_pred_lr = lr_model.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred_lr))

print("\nClassification Report:")
print(classification_report(y_test, y_pred_lr))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred_lr))
# Out:
# Logistic Regression Accuracy: 0.659728981058621
#
# Classification Report:
# c:\Users\Rehan's Lenovo\OneDrive\Desktop\KLH\2-1\ML\github\Road-Accident-Severity-Prediction\.MLvenv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Rehan's Lenovo\OneDrive\Desktop\KLH\2-1\ML\github\Road-Accident-Severity-Prediction\.MLvenv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\Rehan's Lenovo\OneDrive\Desktop\KLH\2-1\ML\github\Road-Accident-Severity-Prediction\.MLvenv\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#                          precision    recall  f1-score   support
#
#          Fatal accident       0.17      0.02      0.04       670
#     Non injury accident       0.00      0.00      0.00         1
#   Other injury accident       0.71      0.81      0.76     24989
# Serious injury accident       0.54      0.42      0.48     14411
#
#                accuracy                           0.66     40071
#               macro avg       0.36      0.31      0.32     40071
#            weighted avg       0.64      0.66      0.64     40071
#
#
# Confusion Matrix:
# [[   14     0   214   442]
#  [    0     0     1     0]
#  [   18     0 20298  4673]
#  [   50     0  8237  6124]]

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(
    max_depth=20,
    random_state=42
)

dt_model.fit(X_train, y_train)

print("Decision Tree training complete.")
